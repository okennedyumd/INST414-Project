# %%
import pandas as pd

# %%
stats = pd.read_csv('Full_NFL_Stats_2022.csv')

# %%
stats.head()
# Out:
#    Unnamed: 0 teamName         displayName  \
# 0           0  Falcons             Fumbles
# 1           1  Falcons        Fumbles Lost
# 2           2  Falcons      Forced Fumbles
# 3           3  Falcons   Fumbles Recovered
# 4           4  Falcons  Fumbles Touchdowns
#
#                                          description abbreviation  value  \
# 0  The number of times a player/team has fumbled ...          FUM   21.0
# 1  The number of times a fumble is recovered by t...          LST   12.0
# 2                The total number of forced fumbles.           FF    8.0
# 3                   The number of fumbles recovered.           FR    7.0
# 4  The number of times a fumbles is recovered and...          FTD    1.0
#
#    perGameValue  rank
# 0           1.0  13.0
# 1           NaN   4.0
# 2           NaN  62.0
# 3           NaN  23.0
# 4           NaN   8.0

# %%
stats.groupby('teamName')

# %%
stats.sort_values('rank',ascending=True)
# Out:
#       Unnamed: 0    teamName                    displayName  \
# 5242          27        Jets              Team Games Played
# 7100          15    Seahawks        One Point Safeties Made
# 4568           1    Patriots  Defensive Fumble Return Yards
# 4567           0    Patriots      Defensive Fumbles Returns
# 4563          39    Patriots              Team Games Played
# ...          ...         ...                            ...
# 6352          41    Chargers     Net Yards Per Pass Attempt
# 7174          41  Buccaneers     Net Yards Per Pass Attempt
# 7448          41  Commanders     Net Yards Per Pass Attempt
# 7722          41    Panthers     Net Yards Per Pass Attempt
# 7996          41     Jaguars     Net Yards Per Pass Attempt
#
#                                             description abbreviation  \
# 5242                        The amount of games played.          TGP
# 7100                            One Point Safeties Made         OPSM
# 4568   The amount of total yardage from fumble returns.       DFRYDS
# 4567                      The number of fumble returns.          DFR
# 4563                  The numbers of team games played.           GP
# ...                                                 ...          ...
# 6352  The average number net yards (taking sack yard...      NYDS/PA
# 7174  The average number net yards (taking sack yard...      NYDS/PA
# 7448  The average number net yards (taking sack yard...      NYDS/PA
# 7722  The average number net yards (taking sack yard...      NYDS/PA
# 7996  The average number net yards (taking sack yard...      NYDS/PA
#
#           value  perGameValue  rank
# 5242  17.000000           NaN   1.0
# 7100   0.000000           NaN   1.0
# 4568   0.000000           NaN   1.0
# 4567   0.000000           NaN   1.0
# 4563  17.000000           NaN   1.0
# ...         ...           ...   ...
# 6352   6.112000      6.255814   NaN
# 7174   5.932730      5.977778   NaN
# 7448   5.767442      6.000000   NaN
# 7722   6.077079      6.285714   NaN
# 7996   6.344551      6.444444   NaN
#
# [8768 rows x 8 columns]

# %%
stats.dropna(subset='rank',inplace=True)

# %%
stats.sort_values('rank',ascending=True)
# Out:
#       Unnamed: 0    teamName                    displayName  \
# 5242          27        Jets              Team Games Played
# 7100          15    Seahawks        One Point Safeties Made
# 4568           1    Patriots  Defensive Fumble Return Yards
# 4567           0    Patriots      Defensive Fumbles Returns
# 4563          39    Patriots              Team Games Played
# ...          ...         ...                            ...
# 6353          42    Chargers             Quarterback Rating
# 7175          42  Buccaneers             Quarterback Rating
# 7156          23  Buccaneers                  Passer Rating
# 4964          23      Giants                  Passer Rating
# 4983          42      Giants             Quarterback Rating
#
#                                            description abbreviation  \
# 5242                       The amount of games played.          TGP
# 7100                           One Point Safeties Made         OPSM
# 4568  The amount of total yardage from fumble returns.       DFRYDS
# 4567                     The number of fumble returns.          DFR
# 4563                 The numbers of team games played.           GP
# ...                                                ...          ...
# 6353                               Quarterback Rating.          RAT
# 7175                               Quarterback Rating.          RAT
# 7156                                     Passer Rating          RTG
# 4964                                     Passer Rating          RTG
# 4983                               Quarterback Rating.          RAT
#
#           value  perGameValue   rank
# 5242  17.000000           NaN    1.0
# 7100   0.000000           NaN    1.0
# 4568   0.000000           NaN    1.0
# 4567   0.000000           NaN    1.0
# 4563  17.000000           NaN    1.0
# ...         ...           ...    ...
# 6353  93.334990     90.188423  102.0
# 7175  89.777500     85.675766  106.0
# 7156  89.777500     85.675766  106.0
# 4964  91.111664     92.513611  114.0
# 4983  91.111664     92.513611  114.0
#
# [8748 rows x 8 columns]

# %%
stats.drop('perGameValue',axis=1)
# Out:
#       Unnamed: 0 teamName          displayName  \
# 0              0  Falcons              Fumbles
# 1              1  Falcons         Fumbles Lost
# 2              2  Falcons       Forced Fumbles
# 3              3  Falcons    Fumbles Recovered
# 4              4  Falcons   Fumbles Touchdowns
# ...          ...      ...                  ...
# 8763          18   Texans      Total Penalties
# 8764          19   Texans  Total Penalty Yards
# 8765          20   Texans      Total Takeaways
# 8766          21   Texans         Total Drives
# 8767          22   Texans       Turnover Ratio
#
#                                             description abbreviation  value  \
# 0     The number of times a player/team has fumbled ...          FUM   21.0
# 1     The number of times a fumble is recovered by t...          LST   12.0
# 2                   The total number of forced fumbles.           FF    8.0
# 3                      The number of fumbles recovered.           FR    7.0
# 4     The number of times a fumbles is recovered and...          FTD    1.0
# ...                                                 ...          ...    ...
# 8763               The total number of total penalties.         TPEN   88.0
# 8764                 The total number of penalty yards.          TPY  644.0
# 8765                     The total number of takeaways.           TT   27.0
# 8766                        The total number of drives.            D    0.0
# 8767       Difference between take-aways and give-aways         DIFF   -1.0
#
#       rank
# 0     13.0
# 1      4.0
# 2     62.0
# 3     23.0
# 4      8.0
# ...    ...
# 8763  24.0
# 8764  29.0
# 8765   4.0
# 8766   1.0
# 8767  16.0
#
# [8748 rows x 7 columns]

# %%
rows = stats.loc[stats['rank'] > 32]
print(rows)
# Out:
#       Unnamed: 0 teamName            displayName  \
# 2              2  Falcons         Forced Fumbles
# 32            23  Falcons          Passer Rating
# 35            26  Falcons   Net Passing Attempts
# 37            28  Falcons  Total Offensive Plays
# 51            42  Falcons     Quarterback Rating
# ...          ...      ...                    ...
# 8271          42   Ravens     Quarterback Rating
# 8331           0   Ravens         Assist Tackles
# 8353          22   Ravens          Total Tackles
# 8526          23   Texans          Passer Rating
# 8545          42   Texans     Quarterback Rating
#
#                                description abbreviation        value  \
# 2      The total number of forced fumbles.           FF     8.000000
# 32                           Passer Rating          RTG    87.693340
# 35                   Net Passing Attempts.         NATT   452.000000
# 37    The number of total offensive plays.          TOP  1011.000000
# 51                     Quarterback Rating.          RAT    87.693340
# ...                                    ...          ...          ...
# 8271                   Quarterback Rating.          RAT    82.526665
# 8331     The number of assists on tackles.          AST   380.000000
# 8353          The total number of tackles.          TOT  1147.000000
# 8526                         Passer Rating          RTG    76.791664
# 8545                   Quarterback Rating.          RAT    76.791664
#
#       perGameValue  rank
# 2              NaN  62.0
# 32       89.001389  79.0
# 35       26.000000  52.0
# 37       58.000000  53.0
# 51       89.001389  79.0
# ...            ...   ...
# 8271     82.521431  79.0
# 8331     20.000000  51.0
# 8353     61.000000  78.0
# 8526     74.833092  79.0
# 8545     74.833092  79.0
#
# [150 rows x 8 columns]

# %%
interceptions = stats.loc[stats['displayName'] == 'Interception Percentage']
interceptions = interceptions.sort_values(by='rank')

# %%
completion = stats.loc[stats['displayName'] == 'Completion Percentage']
completion = completion.sort_values(by='rank')

# %%
pass_rating = stats.loc[stats['displayName'] == 'Passer Rating']
pass_rating = pass_rating.sort_values(by='value',ascending=False)

# %%
touchdowns = stats.loc[stats['description'] == 'The number of touchdowns scored in total.']
touchdowns = touchdowns.drop('rank',axis=1)
touchdowns = touchdowns.drop_duplicates()
touchdowns.sort_values(by='value',ascending=False)
# Out:
#       Unnamed: 0 teamName       displayName  \
# 3259          10   Chiefs  Total Touchdowns
# 3054          31   Chiefs  Total Touchdowns
# 5725          10   Eagles  Total Touchdowns
# 5520          31   Eagles  Total Touchdowns
# 1410          31  Cowboys  Total Touchdowns
# ...          ...      ...               ...
# 5246          31     Jets  Total Touchdowns
# 8534          31   Texans  Total Touchdowns
# 2780          31    Colts  Total Touchdowns
# 2985          10    Colts  Total Touchdowns
# 8739          10   Texans  Total Touchdowns
#
#                                     description abbreviation  value  \
# 3259  The number of touchdowns scored in total.           TD   61.0
# 3054  The number of touchdowns scored in total.           TD   61.0
# 5725  The number of touchdowns scored in total.           TD   59.0
# 5520  The number of touchdowns scored in total.           TD   59.0
# 1410  The number of touchdowns scored in total.           TD   55.0
# ...                                         ...          ...    ...
# 5246  The number of touchdowns scored in total.           TD   29.0
# 8534  The number of touchdowns scored in total.           TD   29.0
# 2780  The number of touchdowns scored in total.           TD   28.0
# 2985  The number of touchdowns scored in total.           TD   28.0
# 8739  The number of touchdowns scored in total.           TD   28.0
#
#       perGameValue
# 3259           3.0
# 3054           3.0
# 5725           3.0
# 5520           3.0
# 1410           3.0
# ...            ...
# 5246           1.0
# 8534           1.0
# 2780           1.0
# 2985           1.0
# 8739           1.0
#
# [64 rows x 7 columns]

# %%
bottom_qb = []

for df in [interceptions, completion, pass_rating]:

    bottom_names = list(df['teamName'].tail(16))

    bottom_qb += bottom_names

name_counts = {name: bottom_qb.count(name) for name in set(bottom_qb)}

final_names = [name for name in name_counts.keys() if name_counts[name] == 3]

print(final_names)
# Out:
# ['Steelers', 'Broncos', 'Texans', 'Bears', 'Raiders', 'Panthers', 'Commanders', 'Ravens']
