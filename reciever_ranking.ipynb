# %%
import pandas as pd

# %%
stats = pd.read_csv('Full_NFL_Stats_2022.csv')

# %%
stats.head()
# Out:
#    Unnamed: 0 teamName         displayName  \
# 0           0  Falcons             Fumbles
# 1           1  Falcons        Fumbles Lost
# 2           2  Falcons      Forced Fumbles
# 3           3  Falcons   Fumbles Recovered
# 4           4  Falcons  Fumbles Touchdowns
#
#                                          description abbreviation  value  \
# 0  The number of times a player/team has fumbled ...          FUM   21.0
# 1  The number of times a fumble is recovered by t...          LST   12.0
# 2                The total number of forced fumbles.           FF    8.0
# 3                   The number of fumbles recovered.           FR    7.0
# 4  The number of times a fumbles is recovered and...          FTD    1.0
#
#    perGameValue  rank
# 0           1.0  13.0
# 1           NaN   4.0
# 2           NaN  62.0
# 3           NaN  23.0
# 4           NaN   8.0

# %%
rec_rat = stats.loc[stats['displayName'] == 'ESPN Widereceiver Rating']
rec_rat = rec_rat.sort_values(by='rank')

# %%
rec_rat.tail()
# Out:
#       Unnamed: 0  teamName               displayName  \
# 8302           1    Ravens  ESPN Widereceiver Rating
# 2548           1    Titans  ESPN Widereceiver Rating
# 7754           1  Panthers  ESPN Widereceiver Rating
# 82             1   Falcons  ESPN Widereceiver Rating
# 630            1     Bears  ESPN Widereceiver Rating
#
#                         description abbreviation   value  perGameValue  rank
# 8302  The ESPN Widereceiver Rating.       ESPNWR  5367.0           NaN  28.0
# 2548  The ESPN Widereceiver Rating.       ESPNWR  5212.0           NaN  29.0
# 7754  The ESPN Widereceiver Rating.       ESPNWR  5141.0           NaN  30.0
# 82    The ESPN Widereceiver Rating.       ESPNWR  4807.0           NaN  31.0
# 630   The ESPN Widereceiver Rating.       ESPNWR  4378.0           NaN  32.0

# %%
targets = stats.loc[stats['displayName'] == 'Receiving Targets']
targets = targets.sort_values(by='rank')

# %%
targets.tail()
# Out:
#       Unnamed: 0  teamName        displayName  \
# 8311          10    Ravens  Receiving Targets
# 2557          10    Titans  Receiving Targets
# 7763          10  Panthers  Receiving Targets
# 91            10   Falcons  Receiving Targets
# 639           10     Bears  Receiving Targets
#
#                                        description abbreviation  value  \
# 8311  The number of times a receiver is thrown to.         TGTS  465.0
# 2557  The number of times a receiver is thrown to.         TGTS  436.0
# 7763  The number of times a receiver is thrown to.         TGTS  427.0
# 91    The number of times a receiver is thrown to.         TGTS  400.0
# 639   The number of times a receiver is thrown to.         TGTS  359.0
#
#       perGameValue  rank
# 8311          27.0  28.0
# 2557          25.0  29.0
# 7763          25.0  30.0
# 91            23.0  31.0
# 639           21.0  32.0

# %%
ypg = stats.loc[stats['displayName'] == 'Receiving Yards Per Game']
ypg = ypg.sort_values(by='rank')

# %%
ypg.tail()
# Out:
#       Unnamed: 0  teamName               displayName  \
# 7768          15  Panthers  Receiving Yards Per Game
# 2562          15    Titans  Receiving Yards Per Game
# 8316          15    Ravens  Receiving Yards Per Game
# 96            15   Falcons  Receiving Yards Per Game
# 644           15     Bears  Receiving Yards Per Game
#
#                                           description abbreviation    value  \
# 7768  The average number of receiving yards per game.        YDS/G  190.941
# 2562  The average number of receiving yards per game.        YDS/G  189.824
# 8316  The average number of receiving yards per game.        YDS/G  188.353
# 96    The average number of receiving yards per game.        YDS/G  172.176
# 644   The average number of receiving yards per game.        YDS/G  152.824
#
#       perGameValue  rank
# 7768           NaN  28.0
# 2562           NaN  29.0
# 8316           NaN  30.0
# 96             NaN  31.0
# 644            NaN  32.0

# %%
rec_td = stats.loc[stats['displayName'] == 'Receiving Touchdowns']
rec_td = rec_td.sort_values(by='value',ascending=False)
rec_td =rec_td.drop_duplicates(subset=['teamName'])

# %%
rec_td.tail()
# Out:
#       Unnamed: 0  teamName           displayName  \
# 3802           5      Rams  Receiving Touchdowns
# 2706           5    Titans  Receiving Touchdowns
# 7764          11  Panthers  Receiving Touchdowns
# 5298          11      Jets  Receiving Touchdowns
# 6268           5  Steelers  Receiving Touchdowns
#
#                                     description abbreviation  value  \
# 3802  The total number of receiving touchdowns.          REC   16.0
# 2706  The total number of receiving touchdowns.          REC   16.0
# 7764  The total number of receiving touchdowns.           TD   16.0
# 5298  The total number of receiving touchdowns.           TD   15.0
# 6268  The total number of receiving touchdowns.          REC   12.0
#
#       perGameValue  rank
# 3802           NaN  28.0
# 2706           NaN  28.0
# 7764           NaN  28.0
# 5298           NaN  31.0
# 6268           NaN  32.0

# %%
bottom_wr = []

for df in [rec_rat, targets, ypg,rec_td]:

    bottom_names = list(df['teamName'].tail(16))

    bottom_wr += bottom_names

name_counts = {name: bottom_wr.count(name) for name in set(bottom_wr)}

final_names = [name for name in name_counts.keys() if name_counts[name] == 4]

print(final_names)
# Out:
# ['Giants', 'Patriots', 'Browns', 'Panthers', 'Ravens', 'Bears', 'Titans', 'Rams', 'Falcons']
